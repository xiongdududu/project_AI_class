# %%
import pygame
from pygame.locals import *
Length = 30  # 棋盘每个点时间的间隔
Node_Numbers = 19  # 棋盘每行/每列点数
Outer_Width = 20  # 棋盘外宽度
Border_Width = 4  # 边框宽度
Inside_Width = 4  # 边框跟实际的棋盘之间的间隔
Border_Length = Length * (Node_Numbers - 1) + Inside_Width * 2 + Border_Width  # 边框线的长度
Start_X = Start_Y = Outer_Width + int(Border_Width / 2) + Inside_Width  # 网格线起点（左上角）坐标
SCREEN_HEIGHT = Length * (Node_Numbers - 1) + Outer_Width * 2 + Border_Width + Inside_Width * 2  # 游戏屏幕的高
SCREEN_WIDTH = SCREEN_HEIGHT + 200  # 游戏屏幕的宽

Radius = Length // 2 - 3  # 棋子半径
Radius2 = Length // 2 + 3
Board_Color = (0xE3, 0x92, 0x65)
#Board_Color = (0xE3, 0x92, 0x65)  # 棋盘颜色
BLACK = (0, 0, 0)
WHITE = (255, 255, 255)
RED = (200, 30, 30)
BLUE = (30, 30, 200)

RIGHT_INFO_POS_X = SCREEN_HEIGHT + Radius2 * 2 + 10
screen = pygame.display.set_mode((SCREEN_WIDTH, SCREEN_HEIGHT))
clock = pygame.time.Clock()
def game_intro():
    intro = True
    while intro:
        for event in pygame.event.get():
#             print(event)
            if event.type == pygame.QUIT:
                pygame.quit()
                quit()
        screen.fill(WHITE)
        button("GO", 200, 100, 30, 30, RED, BLUE,d1)
        
        pygame.display.update()
        clock.tick(15)

def _draw_board(screen):
    # 填充棋盘背景色
    screen.fill(Board_Color)
    # 画棋盘网格线外的边框
    pygame.draw.rect(screen, BLACK, (Outer_Width, Outer_Width, Border_Length, Border_Length), Border_Width)
    # 画网格线
    for i in range(Node_Numbers):
        pygame.draw.line(screen, BLACK,
                         (Start_Y, Start_Y + Length * i),
                         (Start_Y + Length * (Node_Numbers - 1), Start_Y + Length * i),
                         1)
    for j in range(Node_Numbers):
        pygame.draw.line(screen, BLACK,
                         (Start_X + Length * j, Start_X),
                         (Start_X + Length * j, Start_X + Length * (Node_Numbers - 1)),
                         1)
def d1():
    while True:
        for event in pygame.event.get():
            if event.type == pygame.QUIT:
                pygame.quit()
                quit()
        _draw_board(screen)
        pygame.display.update()
        clock.tick(15)


def button (msg, x, y, w, h, ic, ac, action=None):

    mouse =pygame.mouse.get_pos()
    click = pygame.mouse.get_pressed()
#     print(click)
    if x + w > mouse[0] > x and y + h > mouse[1] > y:
        pygame.draw.rect(screen, ac, (x,y,w,h))
        if click[0] == 1 and action != None:
            action()
    else:
        pygame.draw.rect(screen, BLUE, (x,y,w,h))
#     smallText = pygame.font.SysFont('comicsansms', 20)
#     textSurf, textRect = text_objects(msg, smallText)
#     textRect.center = ( (x+(w/2)), (y+(h/2)))
#     gameDisplay.blit(textSurf, textRect)
# while True:
#     pygame.init()
#     screen = pygame.display.set_mode((SCREEN_WIDTH, SCREEN_HEIGHT))  
#     screen.fill(white)
#     pygame.draw.rect(screen, BLUE, ((200,100),(30,30)))
#     pygame.display.update()  
# button("GO", 200, 100, 30, 30, RED, BLUE,d1)
pygame.init()
game_intro()
pygame.quit()
quit()
# Out:
# pygame 1.9.5
# Hello from the pygame community. https://www.pygame.org/contribute.html
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-1-380e0857a8f3> in <module>
#      87 # button("GO", 200, 100, 30, 30, RED, BLUE,d1)
#      88 pygame.init()
# ---> 89 game_intro()
#      90 pygame.quit()
#      91 quit()
#
# <ipython-input-1-380e0857a8f3> in game_intro()
#      32                 quit()
#      33         screen.fill(WHITE)
# ---> 34         button("GO", 200, 100, 30, 30, RED, BLUE,d1)
#      35
#      36         pygame.display.update()
#
# <ipython-input-1-380e0857a8f3> in button(msg, x, y, w, h, ic, ac, action)
#      72         pygame.draw.rect(screen, ac, (x,y,w,h))
#      73         if click[0] == 1 and action != None:
# ---> 74             action()
#      75     else:
#      76         pygame.draw.rect(screen, BLUE, (x,y,w,h))
#
# <ipython-input-1-380e0857a8f3> in d1()
#      59                 pygame.quit()
#      60                 quit()
# ---> 61         _draw_board(screen)
#      62         pygame.display.update()
#      63         clock.tick(15)
#
# <ipython-input-1-380e0857a8f3> in _draw_board(screen)
#      39 def _draw_board(screen):
#      40     # 填充棋盘背景色
# ---> 41     screen.fill(Board_Color)
#      42     # 画棋盘网格线外的边框
#      43     pygame.draw.rect(screen, BLACK, (Outer_Width, Outer_Width, Border_Length, Border_Length), Border_Width)
#
# error: display Surface quit
